# %%
import pandas as pd

# %%
df1 = pd.DataFrame(
    [
        [0.10 , 0.00 , 1.00 ],
        [0.20 , 0.00 , 1.00 ],
        [0.30 , 0.00 , 1.00 ],
        [0.30 , 0.01 , 0.75 ],
        [0.40 , 0.01 , 0.80 ],
        [0.40 , 0.02 , 0.67 ],
        [0.50 , 0.02 , 0.71 ],
        [0.60 , 0.02 , 0.75 ],
        [0.70 , 0.02 , 0.78 ],
        [0.80 , 0.02 , 0.80 ],
        [0.90 , 0.02 , 0.82 ],
        [0.90 , 0.03 , 0.75 ],
        [0.90 , 0.04 , 0.69 ],
        [0.90 , 0.06 , 0.64 ],
        [0.90 , 0.07 , 0.60 ],
        [0.90 , 0.08 , 0.56 ],
        [0.90 , 0.09 , 0.53 ],
        [0.90 , 0.10 , 0.50 ],
        [0.90 , 0.11 , 0.47 ],
        [0.90 , 0.12 , 0.45 ],
        [0.90 , 0.13 , 0.43 ],
        [0.90 , 0.14 , 0.41 ],
        [0.90 , 0.16 , 0.39 ],
        [0.90 , 0.17 , 0.38 ],
        [0.90 , 0.18 , 0.36 ],
        [0.90 , 0.19 , 0.35 ],
        [0.90 , 0.20 , 0.33 ],
        [0.90 , 0.21 , 0.32 ],
        [0.90 , 0.22 , 0.31 ],
        [0.90 , 0.23 , 0.30 ],
        [0.90 , 0.24 , 0.29 ],
        [0.90 , 0.26 , 0.28 ],
        [0.90 , 0.27 , 0.27 ],
        [0.90 , 0.28 , 0.26 ],
        [0.90 , 0.29 , 0.26 ],
        [0.90 , 0.30 , 0.25 ],
        [0.90 , 0.31 , 0.24 ],
        [0.90 , 0.32 , 0.24 ],
        [0.90 , 0.33 , 0.23 ],
        [0.90 , 0.34 , 0.23 ],
        [0.90 , 0.36 , 0.22 ],
        [0.90 , 0.37 , 0.21 ],
        [0.90 , 0.38 , 0.21 ],
        [0.90 , 0.39 , 0.20 ],
        [0.90 , 0.40 , 0.20 ],
        [0.90 , 0.41 , 0.20 ],
        [0.90 , 0.42 , 0.19 ],
        [0.90 , 0.43 , 0.19 ],
        [0.90 , 0.44 , 0.18 ],
        [1.00 , 0.44 , 0.20 ],
        [1.00 , 0.46 , 0.20 ],
        [1.00 , 0.47 , 0.19 ],
        [1.00 , 0.48 , 0.19 ],
        [1.00 , 0.49 , 0.19 ],
        [1.00 , 0.50 , 0.18 ],
        [1.00 , 0.51 , 0.18 ],
        [1.00 , 0.52 , 0.18 ],
        [1.00 , 0.53 , 0.17 ],
        [1.00 , 0.54 , 0.17 ],
        [1.00 , 0.56 , 0.17 ],
        [1.00 , 0.57 , 0.16 ],
        [1.00 , 0.58 , 0.16 ],
        [1.00 , 0.59 , 0.16 ],
        [1.00 , 0.60 , 0.16 ],
        [1.00 , 0.61 , 0.15 ],
        [1.00 , 0.62 , 0.15 ],
        [1.00 , 0.63 , 0.15 ],
        [1.00 , 0.64 , 0.15 ],
        [1.00 , 0.66 , 0.14 ],
        [1.00 , 0.67 , 0.14 ],
        [1.00 , 0.68 , 0.14 ],
        [1.00 , 0.69 , 0.14 ],
        [1.00 , 0.70 , 0.14 ],
        [1.00 , 0.71 , 0.14 ],
        [1.00 , 0.72 , 0.13 ],
        [1.00 , 0.73 , 0.13 ],
        [1.00 , 0.74 , 0.13 ],
        [1.00 , 0.76 , 0.13 ],
        [1.00 , 0.77 , 0.13 ],
        [1.00 , 0.78 , 0.13 ],
        [1.00 , 0.79 , 0.12 ],
        [1.00 , 0.80 , 0.12 ],
        [1.00 , 0.81 , 0.12 ],
        [1.00 , 0.82 , 0.12 ],
        [1.00 , 0.83 , 0.12 ],
        [1.00 , 0.84 , 0.12 ],
        [1.00 , 0.86 , 0.11 ],
        [1.00 , 0.87 , 0.11 ],
        [1.00 , 0.88 , 0.11 ],
        [1.00 , 0.89 , 0.11 ],
        [1.00 , 0.90 , 0.11 ],
        [1.00 , 0.91 , 0.11 ],
        [1.00 , 0.92 , 0.11 ],
        [1.00 , 0.93 , 0.11 ],
        [1.00 , 0.94 , 0.11 ],
        [1.00 , 0.96 , 0.10 ],
        [1.00 , 0.97 , 0.10 ],
        [1.00 , 0.98 , 0.10 ],
        [1.00 , 0.99 , 0.10 ],
        [1.00 , 1.00 , 0.10 ],
    ],
    columns=("TPR", "FPR","Precision")
)

# %%
df2 = pd.DataFrame(
    [
        [0.10 , 0.00 , 1.00 ],
        [0.10 , 0.01 , 0.50 ],
        [0.10 , 0.02 , 0.33 ],
        [0.10 , 0.03 , 0.25 ],
        [0.20 , 0.03 , 0.40 ],
        [0.20 , 0.04 , 0.33 ],
        [0.30 , 0.04 , 0.43 ],
        [0.40 , 0.04 , 0.50 ],
        [0.50 , 0.04 , 0.56 ],
        [0.60 , 0.04 , 0.60 ],
        [0.70 , 0.04 , 0.64 ],
        [0.70 , 0.06 , 0.58 ],
        [0.70 , 0.07 , 0.54 ],
        [0.70 , 0.08 , 0.50 ],
        [0.70 , 0.09 , 0.47 ],
        [0.70 , 0.10 , 0.44 ],
        [0.70 , 0.11 , 0.41 ],
        [0.70 , 0.12 , 0.39 ],
        [0.80 , 0.12 , 0.42 ],
        [0.90 , 0.12 , 0.45 ],
        [0.90 , 0.13 , 0.43 ],
        [0.90 , 0.14 , 0.41 ],
        [0.90 , 0.16 , 0.39 ],
        [0.90 , 0.17 , 0.38 ],
        [0.90 , 0.18 , 0.36 ],
        [0.90 , 0.19 , 0.35 ],
        [0.90 , 0.20 , 0.33 ],
        [0.90 , 0.21 , 0.32 ],
        [0.90 , 0.22 , 0.31 ],
        [0.90 , 0.23 , 0.30 ],
        [0.90 , 0.24 , 0.29 ],
        [0.90 , 0.26 , 0.28 ],
        [0.90 , 0.27 , 0.27 ],
        [0.90 , 0.28 , 0.26 ],
        [0.90 , 0.29 , 0.26 ],
        [0.90 , 0.30 , 0.25 ],
        [0.90 , 0.31 , 0.24 ],
        [0.90 , 0.32 , 0.24 ],
        [0.90 , 0.33 , 0.23 ],
        [0.90 , 0.34 , 0.23 ],
        [0.90 , 0.36 , 0.22 ],
        [0.90 , 0.37 , 0.21 ],
        [0.90 , 0.38 , 0.21 ],
        [0.90 , 0.39 , 0.20 ],
        [0.90 , 0.40 , 0.20 ],
        [0.90 , 0.41 , 0.20 ],
        [0.90 , 0.42 , 0.19 ],
        [0.90 , 0.43 , 0.19 ],
        [0.90 , 0.44 , 0.18 ],
        [1.00 , 0.44 , 0.20 ],
        [1.00 , 0.46 , 0.20 ],
        [1.00 , 0.47 , 0.19 ],
        [1.00 , 0.48 , 0.19 ],
        [1.00 , 0.49 , 0.19 ],
        [1.00 , 0.50 , 0.18 ],
        [1.00 , 0.51 , 0.18 ],
        [1.00 , 0.52 , 0.18 ],
        [1.00 , 0.53 , 0.17 ],
        [1.00 , 0.54 , 0.17 ],
        [1.00 , 0.56 , 0.17 ],
        [1.00 , 0.57 , 0.16 ],
        [1.00 , 0.58 , 0.16 ],
        [1.00 , 0.59 , 0.16 ],
        [1.00 , 0.60 , 0.16 ],
        [1.00 , 0.61 , 0.15 ],
        [1.00 , 0.62 , 0.15 ],
        [1.00 , 0.63 , 0.15 ],
        [1.00 , 0.64 , 0.15 ],
        [1.00 , 0.66 , 0.14 ],
        [1.00 , 0.67 , 0.14 ],
        [1.00 , 0.68 , 0.14 ],
        [1.00 , 0.69 , 0.14 ],
        [1.00 , 0.70 , 0.14 ],
        [1.00 , 0.71 , 0.14 ],
        [1.00 , 0.72 , 0.13 ],
        [1.00 , 0.73 , 0.13 ],
        [1.00 , 0.74 , 0.13 ],
        [1.00 , 0.76 , 0.13 ],
        [1.00 , 0.77 , 0.13 ],
        [1.00 , 0.78 , 0.13 ],
        [1.00 , 0.79 , 0.12 ],
        [1.00 , 0.80 , 0.12 ],
        [1.00 , 0.81 , 0.12 ],
        [1.00 , 0.82 , 0.12 ],
        [1.00 , 0.83 , 0.12 ],
        [1.00 , 0.84 , 0.12 ],
        [1.00 , 0.86 , 0.11 ],
        [1.00 , 0.87 , 0.11 ],
        [1.00 , 0.88 , 0.11 ],
        [1.00 , 0.89 , 0.11 ],
        [1.00 , 0.90 , 0.11 ],
        [1.00 , 0.91 , 0.11 ],
        [1.00 , 0.92 , 0.11 ],
        [1.00 , 0.93 , 0.11 ],
        [1.00 , 0.94 , 0.11 ],
        [1.00 , 0.96 , 0.10 ],
        [1.00 , 0.97 , 0.10 ],
        [1.00 , 0.98 , 0.10 ],
        [1.00 , 0.99 , 0.10 ],
        [1.00 , 1.00 , 0.10 ],
    ],
    columns=("TPR", "FPR","Precision")
)

# %%
df1.head(3)
# Out:
#    TPR  FPR  Precision
# 0  0.1  0.0        1.0
# 1  0.2  0.0        1.0
# 2  0.3  0.0        1.0

# %%
df2.head(3)
# Out:
#    TPR   FPR  Precision
# 0  0.1  0.00       1.00
# 1  0.1  0.01       0.50
# 2  0.1  0.02       0.33

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
plt.plot(df1["TPR"], df1["Precision"], color = "red" ,marker="*",markersize=10)
plt.plot(df2["TPR"], df2["Precision"], color = "blue" ,marker="x",markersize=6)
plt.xlabel("TPR")
plt.ylabel("Precision")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df1["FPR"], df1["TPR"], color = "red" ,marker="*",markersize=10)
plt.plot(df2["FPR"], df2["TPR"], color = "blue" ,marker="x",markersize=6)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.show()

# %%
df3 = pd.DataFrame(
    [
        [0.10 , 0.00 , 1.00  ],
        [0.20 , 0.00 , 1.00  ],
        [0.30 , 0.00 , 1.00  ],
        [0.30 , 0.01 , 0.75  ],
        [0.40 , 0.01 , 0.80  ],
        [0.40 , 0.02 , 0.67  ],
        [0.50 , 0.02 , 0.71  ],
        [0.60 , 0.02 , 0.75  ],
        [0.70 , 0.02 , 0.78  ],
        [0.90 , 0.02 , 0.82  ],
        [0.90 , 0.03 , 0.75  ],
        [0.90 , 0.04 , 0.69  ],
        [0.90 , 0.06 , 0.64  ],
        [0.90 , 0.07 , 0.60  ],
        [0.90 , 0.08 , 0.56  ],
        [0.90 , 0.09 , 0.53  ],
        [0.90 , 0.10 , 0.50  ],
        [0.90 , 0.11 , 0.47  ],
        [0.90 , 0.12 , 0.45  ],
        [0.90 , 0.13 , 0.43  ],
        [0.90 , 0.14 , 0.41  ],
        [0.90 , 0.16 , 0.39  ],
        [0.90 , 0.17 , 0.38  ],
        [0.90 , 0.18 , 0.36  ],
        [0.90 , 0.19 , 0.35  ],
        [0.90 , 0.20 , 0.33  ],
        [0.90 , 0.21 , 0.32  ],
        [0.90 , 0.22 , 0.31  ],
        [0.90 , 0.23 , 0.30  ],
        [0.90 , 0.24 , 0.29  ],
        [0.90 , 0.26 , 0.28  ],
        [0.90 , 0.27 , 0.27  ],
        [0.90 , 0.28 , 0.26  ],
        [0.90 , 0.29 , 0.26  ],
        [0.90 , 0.30 , 0.25  ],
        [0.90 , 0.31 , 0.24  ],
        [0.90 , 0.32 , 0.24  ],
        [0.90 , 0.33 , 0.23  ],
        [0.90 , 0.34 , 0.23  ],
        [0.90 , 0.36 , 0.22  ],
        [0.90 , 0.37 , 0.21  ],
        [0.90 , 0.38 , 0.21  ],
        [0.90 , 0.39 , 0.20  ],
        [0.90 , 0.40 , 0.20  ],
        [0.90 , 0.41 , 0.20  ],
        [0.90 , 0.42 , 0.19  ],
        [0.90 , 0.43 , 0.19  ],
        [0.90 , 0.44 , 0.18  ],
        [0.90 , 0.46 , 0.18  ],
        [0.90 , 0.47 , 0.18  ],
        [0.90 , 0.48 , 0.17  ],
        [0.90 , 0.49 , 0.17  ],
        [0.90 , 0.50 , 0.17  ],
        [0.90 , 0.51 , 0.16  ],
        [0.90 , 0.52 , 0.16  ],
        [0.90 , 0.53 , 0.16  ],
        [0.90 , 0.54 , 0.16  ],
        [0.90 , 0.56 , 0.15  ],
        [0.90 , 0.57 , 0.15  ],
        [0.90 , 0.58 , 0.15  ],
        [0.90 , 0.59 , 0.15  ],
        [0.90 , 0.60 , 0.14  ],
        [0.90 , 0.61 , 0.14  ],
        [0.90 , 0.62 , 0.14  ],
        [0.90 , 0.63 , 0.14  ],
        [0.90 , 0.64 , 0.13  ],
        [0.90 , 0.66 , 0.13  ],
        [0.90 , 0.67 , 0.13  ],
        [0.90 , 0.68 , 0.13  ],
        [0.90 , 0.69 , 0.13  ],
        [0.90 , 0.70 , 0.13  ],
        [0.90 , 0.71 , 0.12  ],
        [0.90 , 0.72 , 0.12  ],
        [0.90 , 0.73 , 0.12  ],
        [0.90 , 0.74 , 0.12  ],
        [0.90 , 0.76 , 0.12  ],
        [0.90 , 0.77 , 0.12  ],
        [0.90 , 0.78 , 0.11  ],
        [0.90 , 0.79 , 0.11  ],
        [0.90 , 0.80 , 0.11  ],
        [0.90 , 0.81 , 0.11  ],
        [0.90 , 0.82 , 0.11  ],
        [0.90 , 0.83 , 0.11  ],
        [0.90 , 0.84 , 0.11  ],
        [0.90 , 0.86 , 0.10  ],
        [0.90 , 0.87 , 0.10  ],
        [0.90 , 0.88 , 0.10  ],
        [0.90 , 0.89 , 0.10  ],
        [0.90 , 0.90 , 0.10  ],
        [0.90 , 0.91 , 0.10  ],
        [0.90 , 0.92 , 0.10  ],
        [0.90 , 0.93 , 0.10  ],
        [0.90 , 0.94 , 0.10  ],
        [0.90 , 0.96 , 0.09  ],
        [0.90 , 0.97 , 0.09  ],
        [0.90 , 0.98 , 0.09  ],
        [0.90 , 0.99 , 0.09  ],
        [0.90 , 1.00 , 0.09  ],
        [1.00 , 1.00 , 0.10  ]
    ],
    columns=("TPR", "FPR","Precision")
)

# %%
plt.figure(figsize=(20,10))
plt.plot(df1["TPR"], df1["Precision"], color = "red" ,marker="*",markersize=10)
plt.plot(df3["TPR"], df3["Precision"], color = "green" ,marker="x",markersize=6)
plt.xlabel("TPR")
plt.ylabel("Precision")
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(df1["FPR"], df1["TPR"], color = "red" ,marker="*",markersize=10)
plt.plot(df3["FPR"], df3["TPR"], color = "green" ,marker="x",markersize=6)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.show()
